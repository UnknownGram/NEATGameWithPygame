# %%
# !pip install pygame
# !pip install neat-python
# Out:
# Requirement already satisfied: pygame in c:\users\21ste\anaconda3\envs\rl\lib\site-packages (2.5.2)
# Requirement already satisfied: neat-python in c:\users\21ste\anaconda3\envs\rl\lib\site-packages (0.92)

# %%
import os
import random
import math
import pygame
from os import listdir
from os.path import isfile, join
import neat
pygame.init()

pygame.display.set_caption("Platformer")

WIDTH, HEIGHT = 1000, 800
FPS = 60
PLAYER_VEL = 5

window = pygame.display.set_mode((WIDTH, HEIGHT))
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def flip(sprites):
    return [pygame.transform.flip(sprite, True, False) for sprite in sprites]


def load_sprite_sheets(dir1, dir2, width, height, direction=False):
    path = join("assets", dir1, dir2)
    images = [f for f in listdir(path) if isfile(join(path, f))]

    all_sprites = {}

    for image in images:
        sprite_sheet = pygame.image.load(join(path, image)).convert_alpha()

        sprites = []
        for i in range(sprite_sheet.get_width() // width):
            surface = pygame.Surface((width, height), pygame.SRCALPHA, 32)
            rect = pygame.Rect(i * width, 0, width, height)
            surface.blit(sprite_sheet, (0, 0), rect)
            sprites.append(pygame.transform.scale2x(surface))

        if direction:
            all_sprites[image.replace(".png", "") + "_right"] = sprites
            all_sprites[image.replace(".png", "") + "_left"] = flip(sprites)
        else:
            all_sprites[image.replace(".png", "")] = sprites

    return all_sprites

# %%
class Player(pygame.sprite.Sprite):
    COLOR = (255, 0, 0)
    GRAVITY = 1
    SPRITES = load_sprite_sheets("MainCharacters", "MaskDude", 32, 32, True)
    ANIMATION_DELAY = 3

    def __init__(self, x, y, width, height):
        super().__init__()
        self.rect = pygame.Rect(x, y, width, height)
        self.x_vel = 0
        self.y_vel = 0
        self.mask = None
        self.direction = "left"
        self.animation_count = 0
        self.fall_count = 0
        self.jump_count = 0
        self.hit = False
        self.hit_count = 0

    def jump(self):
        self.y_vel = -self.GRAVITY * 8
        self.animation_count = 0
        self.jump_count += 1
        if self.jump_count == 1:
            self.fall_count = 0

    def move(self, dx, dy):
        self.rect.x += dx
        self.rect.y += dy

    def make_hit(self):
        self.hit = True

    def move_left(self, vel):
        self.x_vel = -vel
        if self.direction != "left":
            self.direction = "left"
            self.animation_count = 0

    def move_right(self, vel):
        self.x_vel = vel
        if self.direction != "right":
            self.direction = "right"
            self.animation_count = 0

    def loop(self, fps):
        self.y_vel += min(1, (self.fall_count / fps) * self.GRAVITY)
        self.move(self.x_vel, self.y_vel)

        if self.hit:
            self.hit_count += 1
        if self.hit_count > fps * 2:
            self.hit = False
            self.hit_count = 0

        self.fall_count += 1
        self.update_sprite()

    def landed(self):
        self.fall_count = 0
        self.y_vel = 0
        self.jump_count = 0

    def hit_head(self):
        self.count = 0
        self.y_vel *= -1

    def update_sprite(self):
        sprite_sheet = "idle"
        if self.hit:
            sprite_sheet = "hit"
        elif self.y_vel < 0:
            if self.jump_count == 1:
                sprite_sheet = "jump"
            elif self.jump_count == 2:
                sprite_sheet = "double_jump"
        elif self.y_vel > self.GRAVITY * 2:
            sprite_sheet = "fall"
        elif self.x_vel != 0:
            sprite_sheet = "run"

        sprite_sheet_name = sprite_sheet + "_" + self.direction
        sprites = self.SPRITES[sprite_sheet_name]
        sprite_index = (self.animation_count //
                        self.ANIMATION_DELAY) % len(sprites)
        self.sprite = sprites[sprite_index]
        self.animation_count += 1
        self.update()

    def update(self):
        self.rect = self.sprite.get_rect(topleft=(self.rect.x, self.rect.y))
        self.mask = pygame.mask.from_surface(self.sprite)

    def draw(self, win, offset_x):
        win.blit(self.sprite, (self.rect.x - offset_x, self.rect.y))

# %%
def get_block(size):
    path = join("assets", "Terrain", "Terrain.png")
    image = pygame.image.load(path).convert_alpha()
    surface = pygame.Surface((size, size), pygame.SRCALPHA, 32)
    rect = pygame.Rect(96, 0, size, size)
    surface.blit(image, (0, 0), rect)
    return pygame.transform.scale2x(surface)




class Object(pygame.sprite.Sprite):
    def __init__(self, x, y, width, height, name=None):
        super().__init__()
        self.rect = pygame.Rect(x, y, width, height)
        self.image = pygame.Surface((width, height), pygame.SRCALPHA)
        self.width = width
        self.height = height
        self.name = name

    def draw(self, win, offset_x):
        win.blit(self.image, (self.rect.x - offset_x, self.rect.y))


class Block(Object):
    def __init__(self, x, y, size):
        super().__init__(x, y, size, size)
        block = get_block(size)
        self.image.blit(block, (0, 0))
        self.mask = pygame.mask.from_surface(self.image)

# %%
class Fire(Object):
    ANIMATION_DELAY = 3

    def __init__(self, x, y, width, height):
        super().__init__(x, y, width, height, "fire")
        self.fire = load_sprite_sheets("Traps", "Fire", width, height)
        self.image = self.fire["off"][0]
        self.mask = pygame.mask.from_surface(self.image)
        self.animation_count = 0
        self.animation_name = "off"

    def on(self):
        self.animation_name = "on"

    def off(self):
        self.animation_name = "off"

    def loop(self):
        sprites = self.fire[self.animation_name]
        sprite_index = (self.animation_count //
                        self.ANIMATION_DELAY) % len(sprites)
        self.image = sprites[sprite_index]
        self.animation_count += 1

        self.rect = self.image.get_rect(topleft=(self.rect.x, self.rect.y))
        self.mask = pygame.mask.from_surface(self.image)

        if self.animation_count // self.ANIMATION_DELAY > len(sprites):
            self.animation_count = 0

# %%
def get_background(name):
    image = pygame.image.load(join("assets", "Background", name))
    _, _, width, height = image.get_rect()
    tiles = []

    for i in range(WIDTH // width + 1):
        for j in range(HEIGHT // height + 1):
            pos = (i * width, j * height)
            tiles.append(pos)

    return tiles, image


def draw(window, background, bg_image, players, objects, offset_x, playerRemains, generation, curr_score, high_score, time_limit):
    for tile in background:
        window.blit(bg_image, tile)

    text = font.render("players remaining: " + str(playerRemains), True, (0, 0, 0))
    text_rect = text.get_rect()
    text_rect.center = (WIDTH/2, 130)
    window.blit(text, text_rect)

    Gtext = font.render("Generation: " + str(generation), True, (0, 0, 0))
    Gtext_rect = Gtext.get_rect()
    Gtext_rect.center = (WIDTH/2, 100)
    window.blit(Gtext, Gtext_rect)

    curr_score = font.render("Generation High Score: " + str(round(curr_score, 2)), True, (0, 0, 0))
    curr_rect = curr_score.get_rect()
    curr_rect.center = (WIDTH/2, 160)
    window.blit(curr_score, curr_rect)

    highText = font.render("Highest Score Overall: " + str(round(high_score, 2)), True, (0, 0, 0))
    high_rect = highText.get_rect()
    high_rect.center = (WIDTH/2, 190)
    window.blit(highText, high_rect)

    timeText = font.render("Time Limit: " + str(time_limit), True, (0, 0, 0))
    time_rect = timeText.get_rect()
    time_rect.center = (WIDTH/2, 210)
    window.blit(timeText, time_rect)

    for obj in objects:
        obj.draw(window, offset_x)
    
    for player in players:
        player.draw(window, offset_x)

    pygame.display.update()


def handle_vertical_collision(player, objects, dy):
    collided_objects = []
    for obj in objects:
        if pygame.sprite.collide_mask(player, obj):
            if dy > 0:
                player.rect.bottom = obj.rect.top
                player.landed()
            elif dy < 0:
                player.rect.top = obj.rect.bottom
                player.hit_head()

            collided_objects.append(obj)

    return collided_objects


def collide(player, objects, dx):
    player.move(dx, 0)
    player.update()
    collided_object = None
    for obj in objects:
        if pygame.sprite.collide_mask(player, obj):
            collided_object = obj
            break

    player.move(-dx, 0)
    player.update()
    return collided_object


def handle_move(player, objects, action):
    player.x_vel = 0
    collide_left = collide(player, objects, -PLAYER_VEL * 2)
    collide_right = collide(player, objects, PLAYER_VEL * 2)

    if action == "left" and not collide_left:
        player.move_left(PLAYER_VEL)
    if action == "right" and not collide_right:
        player.move_right(PLAYER_VEL)

    vertical_collide = handle_vertical_collision(player, objects, player.y_vel)
    to_check = [collide_left, collide_right, *vertical_collide]

    for obj in to_check:
        if obj and obj.name == "fire":
            player.make_hit()

# %%
clock = pygame.time.Clock()
background, bg_image = get_background("Blue.png")
font = pygame.font.SysFont("Arial", 30)

block_size = 96


fire = Fire(170, 640, 16, 32)
fire2 = Fire(550, 640 - block_size, 16, 32)
fire3 = Fire(750, 640, 16, 32)
fire4 = Fire(1000, 640, 16, 32)
fire5 = Fire(1500, 640, 16, 32)
fire.on()
fire2.on()
fire3.on()
fire4.on()
fire5.on()

floor = [Block(i * block_size, HEIGHT - block_size, block_size)
             for i in range(-WIDTH // block_size, (WIDTH * 2) // block_size)]
#floor = Block(100, HEIGHT - block_size, block_size)

'''win_platform = [Block(i * block_size, HEIGHT - block_size * 6, block_size)
                    for i in range( 10, (WIDTH * 2) // block_size)]'''
    
objects = [*floor, Block(500, HEIGHT - block_size * 2, block_size), fire, fire2, fire3, fire4, fire5]
#Block(block_size * 3 + 500, HEIGHT - block_size * 4, block_size)
generation = 0
high_score = -1000
time_limit = 100

# %%
def eval_genomes(genomes, config):

    offset_x = 0
    scroll_area_width = 200
    #NEAT
    nets = []
    ge = []
    dis = []
        

    #player = Player(100, 100, 50, 50)
    players = []

    for _, g in genomes:
        net = neat.nn.FeedForwardNetwork.create(g, config)
        nets.append(net)
        players.append(Player(10, 640, 50, 50))
        g.fitness = 0
        ge.append(g)
        dis.append(10)

    run = True
    time = 0
    global generation, high_score, time_limit
    generation += 1
    if generation % 5 == 0:
        time_limit += 10
    while run:
        curr_high_score = -1000
        clock.tick(FPS)
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                run = False
                pygame.quit()
                quit()
                break

        for x, player in enumerate(players):
            ge[x].fitness -= 0.08

            #output = nets[x].activate((player.rect.x, player.rect.y, (1 if player.jump_count < 2 else 0),  abs(player.rect.x - 100), abs(player.rect.y - (HEIGHT - block_size)), abs(player.rect.x - 500), abs(player.rect.y - (HEIGHT - block_size * 2)), abs(player.rect.x - (block_size * 3 + 500)), abs(player.rect.y - (HEIGHT - block_size * 4)), abs(player.rect.x - 1725), abs(player.rect.y - 640)))
            output = nets[x].activate((player.rect.x, player.rect.y, (1 if player.jump_count < 2 else 0),  abs(player.rect.x - 170), abs(player.rect.y - 640), abs(player.rect.x - 550), abs(player.rect.y - 554), abs(player.rect.x - 750), abs(player.rect.x - 640), abs(player.rect.x - 1000),  abs(player.rect.y - 640), abs(player.rect.x - 1500), abs(player.rect.y - 640), abs(player.rect.x - 1815)))
            i =  output.index(max(output))
            if i == 0:
                #player.move_left(PLAYER_VEL)
                action = "left"
            elif i == 1:
                #player.move_right(PLAYER_VEL)
                action = "right"
            else:
                if player.jump_count < 2:
                    player.jump()
                action = ""

            '''if ((player.rect.x >= 1725) and (player.rect.y == 160)):
                ge[x].fitness += 5'''

            if (player.rect.x >= 1800):
                ge[x].fitness += 50
            elif dis[x] >= player.rect.x:
                ge[x].fitness -= 0.5
            elif dis[x] < player.rect.x:
                ge[x].fitness += 0.075

            if player.rect.x > 1500:
                ge[x].fitness += 0.05
            elif player.rect.x > 1000:
                ge[x].fitness += 0.04
            elif player.rect.x > 750:
                ge[x].fitness += 0.03
            elif player.rect.x > 550:
                ge[x].fitness += 0.02
            elif player.rect.x > 170:
                ge[x].fitness += 0.01


            '''
            elif player.rect.x >= 1300:
                ge[x].fitness += 0.5
            elif player.rect.x >= 700:
                ge[x].fitness += 0.2'''
            
    
            if ((player.rect.right - offset_x >= WIDTH - scroll_area_width) and player.x_vel > 0) or (
                (player.rect.left - offset_x <= scroll_area_width) and player.x_vel < 0):
                offset_x += player.x_vel
    
            player.loop(FPS)
            handle_move(player, objects, action)

            if curr_high_score < ge[x].fitness:
                curr_high_score = ge[x].fitness

            if player.hit or player.rect.y >= 1200 or player.rect.x < 0 or time > time_limit:
                ge[x].fitness += -500
                players.pop(x)
                nets.pop(x)
                ge.pop(x)
                dis.pop(x)

            if player.rect.x >= 1815:
                players.pop(x)
                nets.pop(x)
                ge.pop(x)
                dis.pop(x)

            
        fire.loop()
        fire2.loop()
        fire3.loop()
        fire4.loop()
        fire5.loop()

        if curr_high_score > high_score:
            high_score = curr_high_score
        draw(window, background, bg_image, players, objects, offset_x, len(players), generation, curr_high_score, high_score, time_limit)
        time += 1
        if len(players) == 0:
            run = False
            break


    #pygame.quit()
    #quit()

# %%
def run(config_path):
    config = neat.config.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_path)
    # Create the population, which is the top-level object for a NEAT run.
    p = neat.Population(config)

    # Add a stdout reporter to show progress in the terminal.
    p.add_reporter(neat.StdOutReporter(True))
    stats = neat.StatisticsReporter()
    p.add_reporter(stats)
    #p.add_reporter(neat.Checkpointer(5))

    # Run for up to 50 generations.
    winner = p.run(eval_genomes, 500)

    # show final stats
    print('\nBest genome:\n{!s}'.format(winner))

# %%
config_path = os.path.join("config.txt")
run(config_path)
pygame.quit()
quit()
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: -508.80410 stdev: 18.45861
# Best fitness: -501.25500 - size: (3, 42) - species 1 - id 12
# Average adjusted fitness: 0.870
# Mean genetic distance 1.209, standard deviation 0.272
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0    50   -501.3    0.870     0
# Total extinctions: 0
# Generation time: 1.809 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: -507.27650 stdev: 17.03217
# Best fitness: -501.25500 - size: (3, 42) - species 1 - id 12
# Average adjusted fitness: 0.896
# Mean genetic distance 1.267, standard deviation 0.315
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1    50   -501.3    0.896     1
# Total extinctions: 0
# Generation time: 1.845 sec (1.827 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: -504.09450 stdev: 11.08577
# Best fitness: -501.25500 - size: (3, 42) - species 1 - id 56
# Average adjusted fitness: 0.950
# Mean genetic distance 1.271, standard deviation 0.365
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2    50   -501.3    0.950     2
# Total extinctions: 0
# Generation time: 1.861 sec (1.838 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: -504.96450 stdev: 13.43792
# Best fitness: -501.25500 - size: (3, 42) - species 1 - id 56
# Average adjusted fitness: 0.936
# Mean genetic distance 1.339, standard deviation 0.362
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3    50   -501.3    0.936     3
# Total extinctions: 0
# Generation time: 1.845 sec (1.840 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: -507.85220 stdev: 18.73323
# Best fitness: -501.25500 - size: (3, 42) - species 1 - id 56
# Average adjusted fitness: 0.895
# Mean genetic distance 1.305, standard deviation 0.478
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4    50   -501.3    0.895     4
# Total extinctions: 0
# Generation time: 2.056 sec (1.883 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: -507.67570 stdev: 18.75084
# Best fitness: -501.25500 - size: (3, 42) - species 1 - id 56
# Average adjusted fitness: 0.898
# Mean genetic distance 1.212, standard deviation 0.420
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5    50   -501.3    0.898     5
# Total extinctions: 0
# Generation time: 2.177 sec (1.932 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: -511.44990 stdev: 23.07212
# Best fitness: -501.25500 - size: (3, 42) - species 1 - id 56
# Average adjusted fitness: 0.840
# Mean genetic distance 1.236, standard deviation 0.360
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6    50   -501.3    0.840     6
# Total extinctions: 0
# Generation time: 2.045 sec (1.948 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: -510.19330 stdev: 21.66740
# Best fitness: -501.25500 - size: (3, 42) - species 1 - id 56
# Average adjusted fitness: 0.860
# Mean genetic distance 1.409, standard deviation 0.342
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7    50   -501.3    0.860     7
# Total extinctions: 0
# Generation time: 2.015 sec (1.957 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: -508.89900 stdev: 20.34833
# Best fitness: -501.25500 - size: (3, 42) - species 1 - id 56
# Average adjusted fitness: 0.880
# Mean genetic distance 1.385, standard deviation 0.384
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8    50   -501.3    0.880     8
# Total extinctions: 0
# Generation time: 2.023 sec (1.964 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: -511.01160 stdev: 23.74620
# Best fitness: -501.25500 - size: (3, 42) - species 1 - id 56
# Average adjusted fitness: 0.860
# Mean genetic distance 1.220, standard deviation 0.367
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9    50   -501.3    0.860     9
# Total extinctions: 0
# Generation time: 2.208 sec (1.989 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: -508.48020 stdev: 20.56209
# Best fitness: -501.25500 - size: (3, 42) - species 1 - id 56
# Average adjusted fitness: 0.895
# Mean genetic distance 1.189, standard deviation 0.318
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10    50   -501.3    0.895    10
# Total extinctions: 0
# Generation time: 2.167 sec (2.024 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: -507.02440 stdev: 18.42265
# Best fitness: -501.25500 - size: (3, 42) - species 1 - id 56
# Average adjusted fitness: 0.916
# Mean genetic distance 1.254, standard deviation 0.363
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11    50   -501.3    0.916    11
# Total extinctions: 0
# Generation time: 2.182 sec (2.058 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: -507.03430 stdev: 18.58372
# Best fitness: -501.25500 - size: (3, 42) - species 1 - id 56
# Average adjusted fitness: 0.916
# Mean genetic distance 1.133, standard deviation 0.361
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12    50   -501.3    0.916    12
# Total extinctions: 0
# Generation time: 2.211 sec (2.093 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: -508.39050 stdev: 20.52951
# Best fitness: -501.25500 - size: (3, 42) - species 1 - id 56
# Average adjusted fitness: 0.897
# Mean genetic distance 1.219, standard deviation 0.323
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13    50   -501.3    0.897    13
# Total extinctions: 0
# Generation time: 2.218 sec (2.130 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: -504.53980 stdev: 14.47932
# Best fitness: -501.25500 - size: (3, 42) - species 1 - id 56
# Average adjusted fitness: 0.956
# Mean genetic distance 1.095, standard deviation 0.309
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14    50   -501.3    0.956    14
# Total extinctions: 0
# Generation time: 2.332 sec (2.158 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: -504.48000 stdev: 14.36780
# Best fitness: -501.25500 - size: (3, 42) - species 1 - id 56
# Average adjusted fitness: 0.957
# Mean genetic distance 1.070, standard deviation 0.290
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15    50   -501.3    0.957    15
# Total extinctions: 0
# Generation time: 2.356 sec (2.176 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: -511.74180 stdev: 25.68764
# Best fitness: -501.25500 - size: (3, 42) - species 1 - id 56
# Average adjusted fitness: 0.861
# Mean genetic distance 1.147, standard deviation 0.289
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16    50   -501.3    0.861    16
# Total extinctions: 0
# Generation time: 2.386 sec (2.210 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: -503.00510 stdev: 10.43484
# Best fitness: -501.25500 - size: (3, 42) - species 1 - id 56
# Average adjusted fitness: 0.977
# Mean genetic distance 1.250, standard deviation 0.346
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17    50   -501.3    0.977    17
# Total extinctions: 0
# Generation time: 2.310 sec (2.239 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: -507.68990 stdev: 20.06969
# Best fitness: -501.25500 - size: (3, 42) - species 1 - id 56
# Average adjusted fitness: 0.913
# Mean genetic distance 1.236, standard deviation 0.332
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18    50   -501.3    0.913    18
# Total extinctions: 0
# Generation time: 2.530 sec (2.290 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: -508.32470 stdev: 21.67174
# Best fitness: -501.25500 - size: (3, 42) - species 1 - id 56
# Average adjusted fitness: 0.912
# Mean genetic distance 1.216, standard deviation 0.320
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19
 - size: (3, 42) - species 1 - id 1371
# Average adjusted fitness: 0.932
# Mean genetic distance 1.167, standard deviation 0.380
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   50    50   -500.5    0.932     1
# Total extinctions: 0
# Generation time: 3.550 sec (3.384 average)
#
#  ****** Running generation 51 ******
#
# Population's average fitness: -513.48720 stdev: 34.56002
# Best fitness: -500.49000 - size: (3, 42) - species 1 - id 1371
# Average adjusted fitness: 0.888
# Mean genetic distance 1.186, standard deviation 0.409
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   51    50   -500.5    0.888     2
# Total extinctions: 0
# Generation time: 3.572 sec (3.417 average)
#
#  ****** Running generation 52 ******
#
# Population's average fitness: -517.56000 stdev: 39.88988
# Best fitness: -500.49000 - size: (3, 42) - species 1 - id 1371
# Average adjusted fitness: 0.854
# Mean genetic distance 1.247, standard deviation 0.367
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   52    50   -500.5    0.854     3
# Total extinctions: 0
# Generation time: 3.525 sec (3.439 average)
#
#  ****** Running generation 53 ******
#
# Population's average fitness: -508.82860 stdev: 27.06090
# Best fitness: -500.49000 - size: (3, 42) - species 1 - id 1371
# Average adjusted fitness: 0.928
# Mean genetic distance 1.138, standard deviation 0.385
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   53    50   -500.5    0.928     4
# Total extinctions: 0
# Generation time: 3.544 sec (3.471 average)
#
#  ****** Running generation 54 ******
#
# Population's average fitness: -503.98240 stdev: 16.69113
# Best fitness: -500.44000 - size: (3, 42) - species 1 - id 1371
# Average adjusted fitness: 0.971
# Mean genetic distance 1.080, standard deviation 0.352
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   54    50   -500.4    0.971     0
# Total extinctions: 0
# Generation time: 3.724 sec (3.502 average)
#
#  ****** Running generation 55 ******
#
# Population's average fitness: -511.47750 stdev: 32.64528
# Best fitness: -500.44000 - size: (3, 42) - species 1 - id 1371
# Average adjusted fitness: 0.909
# Mean genetic distance 1.133, standard deviation 0.286
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   55    50   -500.4    0.909     1
# Total extinctions: 0
# Generation time: 3.794 sec (3.546 average)
#
#  ****** Running generation 56 ******
#
# Population's average fitness: -504.00650 stdev: 16.68810
# Best fitness: -500.44000 - size: (3, 42) - species 1 - id 1371
# Average adjusted fitness: 0.970
# Mean genetic distance 1.132, standard deviation 0.342
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   56    50   -500.4    0.970     2
# Total extinctions: 0
# Generation time: 3.642 sec (3.564 average)
#
#  ****** Running generation 57 ******
#
# Population's average fitness: -521.39900 stdev: 44.04047
# Best fitness: -500.44000 - size: (3, 42) - species 1 - id 1371
# Average adjusted fitness: 0.829
# Mean genetic distance 1.261, standard deviation 0.343
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   57    50   -500.4    0.829     3
# Total extinctions: 0
# Generation time: 3.738 sec (3.600 average)
#
#  ****** Running generation 58 ******
#
# Population's average fitness: -506.27410 stdev: 23.46841
# Best fitness: -500.44000 - size: (3, 42) - species 1 - id 1371
# Average adjusted fitness: 0.952
# Mean genetic distance 1.330, standard deviation 0.249
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   58    50   -500.4    0.952     4
# Total extinctions: 0
# Generation time: 3.668 sec (3.630 average)
#
#  ****** Running generation 59 ******
#
# Population's average fitness: -509.02920 stdev: 29.96085
# Best fitness: -500.39000 - size: (3, 42) - species 1 - id 1371
# Average adjusted fitness: 0.932
# Mean genetic distance 1.223, standard deviation 0.356
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   59    50   -500.4    0.932     0
# Total extinctions: 0
# Generation time: 3.893 sec (3.665 average)
#
#  ****** Running generation 60 ******
#
# Population's average fitness: -504.33470 stdev: 17.76566
# Best fitness: -500.39000 - size: (3, 42) - species 1 - id 1371
# Average adjusted fitness: 0.969
# Mean genetic distance 1.141, standard deviation 0.387
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   60    50   -500.4    0.969     1
# Total extinctions: 0
# Generation time: 3.849 sec (3.695 average)
#
#  ****** Running generation 61 ******
#
# Population's average fitness: -511.64750 stdev: 34.19724
# Best fitness: -500.39000 - size: (3, 42) - species 1 - id 1371
# Average adjusted fitness: 0.912
# Mean genetic distance 1.164, standard deviation 0.371
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   61    50   -500.4    0.912     2
# Total extinctions: 0
# Generation time: 3.872 sec (3.725 average)
#
#  ****** Running generation 62 ******
#
# Population's average fitness: -506.74220 stdev: 24.57797
# Best fitness: -500.39000 - size: (3, 42) - species 1 - id 1371
# Average adjusted fitness: 0.950
# Mean genetic distance 1.116, standard deviation 0.274
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   62    50   -500.4    0.950     3
# Total extinctions: 0
# Generation time: 3.912 sec (3.764 average)
#
#  ****** Running generation 63 ******
#
# Population's average fitness: -506.72820 stdev: 24.71511
# Best fitness: -500.39000 - size: (3, 42) - species 1 - id 1371
# Average adjusted fitness: 0.950
# Mean genetic distance 1.126, standard deviation 0.265
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   63    50   -500.4    0.950     4
# Total extinctions: 0
# Generation time: 3.837 sec (3.793 average)
#
#  ****** Running generation 64 ******
#
# Population's average fitness: -506.60190 stdev: 25.70869
# Best fitness: -500.34000 - size: (3, 42) - species 1 - id 1371
# Average adjusted fitness: 0.953
# Mean genetic distance 1.183, standard deviation 0.288
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   64    50   -500.3    0.953     0
# Total extinctions: 0
# Generation time: 4.005 sec (3.821 average)
#
#  ****** Running generation 65 ******
#
# Population's average fitness: -517.41260 stdev: 43.08420
# Best fitness: -500.34000 - size: (3, 42) - species 1 - id 1371
# Average adjusted fitness: 0.873
# Mean genetic distance 1.127, standard deviation 0.317
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   65    50   -500.3    0.873     1
# Total extinctions: 0
# Generation time: 4.020 sec (3.844 average)
#
#  ****** Running generation 66 ******
#
# Population's average fitness: -522.65390 stdev: 48.53187
# Best fitness: -500.34000 - size: (3, 42) - species 1 - id 1371
# Average adjusted fitness: 0.834
# Mean genetic distance 1.068, standard deviation 0.355
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   66    50   -500.3    0.834     2
# Total extinctions: 0
# Generation time: 4.114 sec (3.891 average)
#
#  ****** Running generation 67 ******
#
# Population's average fitness: -522.79000 stdev: 48.43023
# Best fitness: -500.34000 - size: (3, 42) - species 1 - id 1371
# Average adjusted fitness: 0.833
# Mean genetic distance 1.076, standard deviation 0.283
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   67    50   -500.3    0.833     3
# Total extinctions: 0
# Generation time: 4.133 sec (3.930 average)
#
#  ****** Running generation 68 ******
#
# Population's average fitness: -509.52420 stdev: 31.42917
# Best fitness: -500.34000 - size: (3, 42) - species 1 - id 1371
# Average adjusted fitness: 0.931
# Mean genetic distance 1.138, standard deviation 0.322
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   68    50   -500.3    0.931     4
# Total extinctions: 0
# Generation time: 4.036 sec (3.967 average)
#
#  ****** Running generation 69 ******
#
# Population's average fitness: -512.36820 stdev: 37.36017
# Best fitness: -500.29000 - size: (3, 42) - species 1 - id 1371
# Average adjusted fitness: 0.913
# Mean genetic distance 1.182, standard deviation 0.278
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   69    50   -500.3    0.913     0
# Total extinctions: 0
# Generation time: 4.226 sec (4.000 average)
#
#  ****** Running generation 70 ******
#
# Population's average fitness: -515.26540 stdev: 41.23774
# Best fitness: -500.29000 - size: (3, 42) - species 1 - id 1371
# Average adjusted fitness: 0.893
# Mean genetic distance 1.118, standard deviation 0.325
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   70    50   -500.3    0.893     1
# Total extinctions: 0
# Generation time: 4.551 sec (4.071 average)
#
#  ****** Running generation 71 ******
#
# Population's average fitness: -506.98480 stdev: 27.05327
# Best fitness: -500.29000 - size: (3, 42) - species 1 - id 1371
# Average adjusted fitness: 0.952
# Mean genetic distance 1.124, standard deviation 0.269
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   71    50   -500.3    0.952     2
# Total extinctions: 0
# Generation time: 4.438 sec (4.127 average)
#
#  ****** Running generation 72 ******
#
# Population's average fitness: -515.26650 stdev: 41.31444
# Best fitness: -500.29000 - size: (3, 42) - species 1 - id 1371
# Average adjusted fitness: 0.893
# Mean genetic distance 1.145, standard deviation 0.290
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   72    50   -500.3    0.893     3
# Total extinctions: 0
# Generation time: 4.201 sec (4.156 average)
#
#  ****** Running generation 73 ******

# %%
pygame.quit()
quit()

# %%
#!git clone https://github.com/techwithtim/Python-Platformer.git
